# %%
# importing pandas to use in code
import pandas as pd

# %%
# reading excels into various dataframes
df1 = pd.read_excel("/content/week1_cleaned.xlsx")
df2 = pd.read_excel("/content/week29_cleaned.xlsx")
df3 = pd.read_excel("/content/week45_cleaned.xlsx")
df4 = pd.read_excel("/content/food1_cycle03.xlsx")

# %%
# renaming dataframe columns
df1.rename(columns={
    'Select Characteristics': 'Select Characteristics',
    'Unnamed: 1': '1_total',
    'Unnamed: 2': '1_enough_and_all_food',
    'Unnamed: 3': '1_enough_and_some_food',
    'Unnamed: 4': '1_sometimes_not_enough',
    'Unnamed: 5': '1_often_not_enough',
    'Unnamed: 6': '1_did_no_report'
}, inplace=True)

df2.rename(columns={
    'Select Characteristics': 'Select Characteristics',
    'Unnamed: 1': '2_total',
    'Unnamed: 2': '2_enough_and_all_food',
    'Unnamed: 3': '2_enough_and_some_food',
    'Unnamed: 4': '2_sometimes_not_enough',
    'Unnamed: 5': '2_often_not_enough',
    'Unnamed: 6': '2_did_no_report'
}, inplace=True)

df3.rename(columns={
    'Select Characteristica': 'Select Characteristics',
    'Unnamed: 1': '3_total',
    'Unnamed: 2': '3_enough_and_all_food',
    'Unnamed: 3': '3_enough_and_some_food',
    'Unnamed: 4': '3_sometimes_not_enough',
    'Unnamed: 5': '3_often_not_enough',
    'Unnamed: 6': '3_did_no_report'
}, inplace=True)

df4.rename(columns={
    'Unnamed: 0': 'Select Characteristics',
    'Unnamed: 1': 'total',
    'Unnamed: 2': 'enough_and_all_food',
    'Unnamed: 3': 'enough_and_some_food',
    'Unnamed: 4': 'sometimes_not_enough',
    'Unnamed: 5': 'often_not_enough',
    'Unnamed: 6': 'did_no_report'
}, inplace=True)

# dropping characteristic columns so that theres no overlap
df2nohead = df2.drop(columns='Select Characteristics')
df3nohead = df3.drop(columns='Select Characteristics')

# %%
# create spending DF
df_spending = pd.concat([df2.iloc[59:68].reset_index(drop=True), df3nohead.iloc[74:-1].reset_index(drop=True)], axis=1)
df_spending["total"] = df_spending["2_total"] + df_spending["3_total"]

df_spending.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6908" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6908_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_d6908_level0_col1" class="col_heading level0 col1" >2_total</th>
#       <th id="T_d6908_level0_col2" class="col_heading level0 col2" >2_enough_and_all_food</th>
#       <th id="T_d6908_level0_col3" class="col_heading level0 col3" >2_enough_and_some_food</th>
#       <th id="T_d6908_level0_col4" class="col_heading level0 col4" >2_sometimes_not_enough</th>
#       <th id="T_d6908_level0_col5" class="col_heading level0 col5" >2_often_not_enough</th>
#       <th id="T_d6908_level0_col6" class="col_heading level0 col6" >2_did_no_report</th>
#       <th id="T_d6908_level0_col7" class="col_heading level0 col7" >3_total</th>
#       <th id="T_d6908_level0_col8" class="col_heading level0 col8" >3_enough_and_all_food</th>
#       <th id="T_d6908_level0_col9" class="col_heading level0 col9" >3_enough_and_some_food</th>
#       <th id="T_d6908_level0_col10" class="col_heading level0 col10" >3_sometimes_not_enough</th>
#       <th id="T_d6908_level0_col11" class="col_heading level0 col11" >3_often_not_enough</th>
#       <th id="T_d6908_level0_col12" class="col_heading level0 col12" >3_did_no_report</th>
#       <th id="T_d6908_level0_col13" class="col_heading level0 col13" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6908_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6908_row0_col0" class="data row0 col0" >    Regular income sources like those received before the pandemic</td>
#       <td id="T_d6908_row0_col1" class="data row0 col1" >157720993</td>
#       <td id="T_d6908_row0_col2" class="data row0 col2" >125757576</td>
#       <td id="T_d6908_row0_col3" class="data row0 col3" >24278613</td>
#       <td id="T_d6908_row0_col4" class="data row0 col4" >5421285</td>
#       <td id="T_d6908_row0_col5" class="data row0 col5" >990163</td>
#       <td id="T_d6908_row0_col6" class="data row0 col6" >1273357</td>
#       <td id="T_d6908_row0_col7" class="data row0 col7" >57000098</td>
#       <td id="T_d6908_row0_col8" class="data row0 col8" >35647002</td>
#       <td id="T_d6908_row0_col9" class="data row0 col9" >15789477</td>
#       <td id="T_d6908_row0_col10" class="data row0 col10" >3720254</td>
#       <td id="T_d6908_row0_col11" class="data row0 col11" >1317474</td>
#       <td id="T_d6908_row0_col12" class="data row0 col12" >525890</td>
#       <td id="T_d6908_row0_col13" class="data row0 col13" >214721091</td>
#     </tr>
#     <tr>
#       <th id="T_d6908_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6908_row1_col0" class="data row1 col0" >    Credit cards or loans</td>
#       <td id="T_d6908_row1_col1" class="data row1 col1" >54645825</td>
#       <td id="T_d6908_row1_col2" class="data row1 col2" >32294484</td>
#       <td id="T_d6908_row1_col3" class="data row1 col3" >15587943</td>
#       <td id="T_d6908_row1_col4" class="data row1 col4" >5174040</td>
#       <td id="T_d6908_row1_col5" class="data row1 col5" >1054888</td>
#       <td id="T_d6908_row1_col6" class="data row1 col6" >534470</td>
#       <td id="T_d6908_row1_col7" class="data row1 col7" >27096139</td>
#       <td id="T_d6908_row1_col8" class="data row1 col8" >12614565</td>
#       <td id="T_d6908_row1_col9" class="data row1 col9" >9842363</td>
#       <td id="T_d6908_row1_col10" class="data row1 col10" >3169878</td>
#       <td id="T_d6908_row1_col11" class="data row1 col11" >1188492</td>
#       <td id="T_d6908_row1_col12" class="data row1 col12" >280842</td>
#       <td id="T_d6908_row1_col13" class="data row1 col13" >81741964</td>
#     </tr>
#     <tr>
#       <th id="T_d6908_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6908_row2_col0" class="data row2 col0" >    Money from savings or selling assets or possessions</td>
#       <td id="T_d6908_row2_col1" class="data row2 col1" >41521270</td>
#       <td id="T_d6908_row2_col2" class="data row2 col2" >21636887</td>
#       <td id="T_d6908_row2_col3" class="data row2 col3" >13793144</td>
#       <td id="T_d6908_row2_col4" class="data row2 col4" >4594597</td>
#       <td id="T_d6908_row2_col5" class="data row2 col5" >1040768</td>
#       <td id="T_d6908_row2_col6" class="data row2 col6" >455875</td>
#       <td id="T_d6908_row2_col7" class="data row2 col7" >18431260</td>
#       <td id="T_d6908_row2_col8" class="data row2 col8" >7569152</td>
#       <td id="T_d6908_row2_col9" class="data row2 col9" >7496471</td>
#       <td id="T_d6908_row2_col10" class="data row2 col10" >2460227</td>
#       <td id="T_d6908_row2_col11" class="data row2 col11" >765429</td>
#       <td id="T_d6908_row2_col12" class="data row2 col12" >139981</td>
#       <td id="T_d6908_row2_col13" class="data row2 col13" >59952530</td>
#     </tr>
#     <tr>
#       <th id="T_d6908_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6908_row3_col0" class="data row3 col0" >    Borrowing from friends or family</td>
#       <td id="T_d6908_row3_col1" class="data row3 col1" >18837177</td>
#       <td id="T_d6908_row3_col2" class="data row3 col2" >4405538</td>
#       <td id="T_d6908_row3_col3" class="data row3 col3" >6426890</td>
#       <td id="T_d6908_row3_col4" class="data row3 col4" >6266183</td>
#       <td id="T_d6908_row3_col5" class="data row3 col5" >1536510</td>
#       <td id="T_d6908_row3_col6" class="data row3 col6" >202055</td>
#       <td id="T_d6908_row3_col7" class="data row3 col7" >13376748</td>
#       <td id="T_d6908_row3_col8" class="data row3 col8" >2449029</td>
#       <td id="T_d6908_row3_col9" class="data row3 col9" >5392450</td>
#       <td id="T_d6908_row3_col10" class="data row3 col10" >3912511</td>
#       <td id="T_d6908_row3_col11" class="data row3 col11" >1498988</td>
#       <td id="T_d6908_row3_col12" class="data row3 col12" >123771</td>
#       <td id="T_d6908_row3_col13" class="data row3 col13" >32213925</td>
#     </tr>
#     <tr>
#       <th id="T_d6908_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6908_row4_col0" class="data row4 col0" >    Unemployment insurance (UI) benefit payments</td>
#       <td id="T_d6908_row4_col1" class="data row4 col1" >15322178</td>
#       <td id="T_d6908_row4_col2" class="data row4 col2" >7581719</td>
#       <td id="T_d6908_row4_col3" class="data row4 col3" >5115826</td>
#       <td id="T_d6908_row4_col4" class="data row4 col4" >1989045</td>
#       <td id="T_d6908_row4_col5" class="data row4 col5" >415869</td>
#       <td id="T_d6908_row4_col6" class="data row4 col6" >219718</td>
#       <td id="T_d6908_row4_col7" class="data row4 col7" >1253187</td>
#       <td id="T_d6908_row4_col8" class="data row4 col8" >457225</td>
#       <td id="T_d6908_row4_col9" class="data row4 col9" >305308</td>
#       <td id="T_d6908_row4_col10" class="data row4 col10" >248216</td>
#       <td id="T_d6908_row4_col11" class="data row4 col11" >230447</td>
#       <td id="T_d6908_row4_col12" class="data row4 col12" >11991</td>
#       <td id="T_d6908_row4_col13" class="data row4 col13" >16575365</td>
#     </tr>
#     <tr>
#       <th id="T_d6908_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d6908_row5_col0" class="data row5 col0" >    Stimulus (economic impact) payment</td>
#       <td id="T_d6908_row5_col1" class="data row5 col1" >58589746</td>
#       <td id="T_d6908_row5_col2" class="data row5 col2" >32444836</td>
#       <td id="T_d6908_row5_col3" class="data row5 col3" >18071086</td>
#       <td id="T_d6908_row5_col4" class="data row5 col4" >6320701</td>
#       <td id="T_d6908_row5_col5" class="data row5 col5" >1188932</td>
#       <td id="T_d6908_row5_col6" class="data row5 col6" >564190</td>
#       <td id="T_d6908_row5_col7" class="data row5 col7" >7876994</td>
#       <td id="T_d6908_row5_col8" class="data row5 col8" >2995964</td>
#       <td id="T_d6908_row5_col9" class="data row5 col9" >3010052</td>
#       <td id="T_d6908_row5_col10" class="data row5 col10" >1273665</td>
#       <td id="T_d6908_row5_col11" class="data row5

# %%
# create df for 2024 data
df_age24 = pd.concat([df4.iloc[2:7].reset_index(drop=True)], axis=1)

df_age24.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7837" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7837_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_b7837_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_b7837_level0_col2" class="col_heading level0 col2" >enough_and_all_food</th>
#       <th id="T_b7837_level0_col3" class="col_heading level0 col3" >enough_and_some_food</th>
#       <th id="T_b7837_level0_col4" class="col_heading level0 col4" >sometimes_not_enough</th>
#       <th id="T_b7837_level0_col5" class="col_heading level0 col5" >often_not_enough</th>
#       <th id="T_b7837_level0_col6" class="col_heading level0 col6" >did_no_report</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7837_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7837_row0_col0" class="data row0 col0" >    18 – 24</td>
#       <td id="T_b7837_row0_col1" class="data row0 col1" >15745224.000000</td>
#       <td id="T_b7837_row0_col2" class="data row0 col2" >6006842.000000</td>
#       <td id="T_b7837_row0_col3" class="data row0 col3" >3677798.000000</td>
#       <td id="T_b7837_row0_col4" class="data row0 col4" >1225101.000000</td>
#       <td id="T_b7837_row0_col5" class="data row0 col5" >281450.000000</td>
#       <td id="T_b7837_row0_col6" class="data row0 col6" >4554034.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b7837_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7837_row1_col0" class="data row1 col0" >    25 – 39</td>
#       <td id="T_b7837_row1_col1" class="data row1 col1" >73010092.000000</td>
#       <td id="T_b7837_row1_col2" class="data row1 col2" >32590965.000000</td>
#       <td id="T_b7837_row1_col3" class="data row1 col3" >21684959.000000</td>
#       <td id="T_b7837_row1_col4" class="data row1 col4" >5600385.000000</td>
#       <td id="T_b7837_row1_col5" class="data row1 col5" >2327012.000000</td>
#       <td id="T_b7837_row1_col6" class="data row1 col6" >10806771.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b7837_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7837_row2_col0" class="data row2 col0" >    40 – 54</td>
#       <td id="T_b7837_row2_col1" class="data row2 col1" >65892443.000000</td>
#       <td id="T_b7837_row2_col2" class="data row2 col2" >30135064.000000</td>
#       <td id="T_b7837_row2_col3" class="data row2 col3" >18071080.000000</td>
#       <td id="T_b7837_row2_col4" class="data row2 col4" >5997918.000000</td>
#       <td id="T_b7837_row2_col5" class="data row2 col5" >1915420.000000</td>
#       <td id="T_b7837_row2_col6" class="data row2 col6" >9772961.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b7837_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7837_row3_col0" class="data row3 col0" >    55 – 64</td>
#       <td id="T_b7837_row3_col1" class="data row3 col1" >42324979.000000</td>
#       <td id="T_b7837_row3_col2" class="data row3 col2" >21389369.000000</td>
#       <td id="T_b7837_row3_col3" class="data row3 col3" >10968993.000000</td>
#       <td id="T_b7837_row3_col4" class="data row3 col4" >2652366.000000</td>
#       <td id="T_b7837_row3_col5" class="data row3 col5" >808474.000000</td>
#       <td id="T_b7837_row3_col6" class="data row3 col6" >6505777.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b7837_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b7837_row4_col0" class="data row4 col0" >    65 and above</td>
#       <td id="T_b7837_row4_col1" class="data row4 col1" >59338822.000000</td>
#       <td id="T_b7837_row4_col2" class="data row4 col2" >36005984.000000</td>
#       <td id="T_b7837_row4_col3" class="data row4 col3" >13340270.000000</td>
#       <td id="T_b7837_row4_col4" class="data row4 col4" >1897607.000000</td>
#       <td id="T_b7837_row4_col5" class="data row4 col5" >514625.000000</td>
#       <td id="T_b7837_row4_col6" class="data row4 col6" >7580336.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# copying AGE characteristics from previous dfs to new dataframe
df_age = pd.concat([df1.iloc[1:6].reset_index(drop=True), df2nohead.iloc[1:6].reset_index(drop=True), df3nohead.iloc[1:6].reset_index(drop=True)], axis=1)
df_age["total"] = df_age["1_total"] + df_age["2_total"] + df_age["3_total"]

df_age.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_60e16" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60e16_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_60e16_level0_col1" class="col_heading level0 col1" >1_total</th>
#       <th id="T_60e16_level0_col2" class="col_heading level0 col2" >1_enough_and_all_food</th>
#       <th id="T_60e16_level0_col3" class="col_heading level0 col3" >1_enough_and_some_food</th>
#       <th id="T_60e16_level0_col4" class="col_heading level0 col4" >1_sometimes_not_enough</th>
#       <th id="T_60e16_level0_col5" class="col_heading level0 col5" >1_often_not_enough</th>
#       <th id="T_60e16_level0_col6" class="col_heading level0 col6" >1_did_no_report</th>
#       <th id="T_60e16_level0_col7" class="col_heading level0 col7" >2_total</th>
#       <th id="T_60e16_level0_col8" class="col_heading level0 col8" >2_enough_and_all_food</th>
#       <th id="T_60e16_level0_col9" class="col_heading level0 col9" >2_enough_and_some_food</th>
#       <th id="T_60e16_level0_col10" class="col_heading level0 col10" >2_sometimes_not_enough</th>
#       <th id="T_60e16_level0_col11" class="col_heading level0 col11" >2_often_not_enough</th>
#       <th id="T_60e16_level0_col12" class="col_heading level0 col12" >2_did_no_report</th>
#       <th id="T_60e16_level0_col13" class="col_heading level0 col13" >3_total</th>
#       <th id="T_60e16_level0_col14" class="col_heading level0 col14" >3_enough_and_all_food</th>
#       <th id="T_60e16_level0_col15" class="col_heading level0 col15" >3_enough_and_some_food</th>
#       <th id="T_60e16_level0_col16" class="col_heading level0 col16" >3_sometimes_not_enough</th>
#       <th id="T_60e16_level0_col17" class="col_heading level0 col17" >3_often_not_enough</th>
#       <th id="T_60e16_level0_col18" class="col_heading level0 col18" >3_did_no_report</th>
#       <th id="T_60e16_level0_col19" class="col_heading level0 col19" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60e16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60e16_row0_col0" class="data row0 col0" >    18 - 24</td>
#       <td id="T_60e16_row0_col1" class="data row0 col1" >15224273</td>
#       <td id="T_60e16_row0_col2" class="data row0 col2" >9828389</td>
#       <td id="T_60e16_row0_col3" class="data row0 col3" >4036390</td>
#       <td id="T_60e16_row0_col4" class="data row0 col4" >988302</td>
#       <td id="T_60e16_row0_col5" class="data row0 col5" >128515</td>
#       <td id="T_60e16_row0_col6" class="data row0 col6" >242676</td>
#       <td id="T_60e16_row0_col7" class="data row0 col7" >23445638</td>
#       <td id="T_60e16_row0_col8" class="data row0 col8" >10283478</td>
#       <td id="T_60e16_row0_col9" class="data row0 col9" >3717851</td>
#       <td id="T_60e16_row0_col10" class="data row0 col10" >1306372</td>
#       <td id="T_60e16_row0_col11" class="data row0 col11" >208437</td>
#       <td id="T_60e16_row0_col12" class="data row0 col12" >7929500</td>
#       <td id="T_60e16_row0_col13" class="data row0 col13" >6279144</td>
#       <td id="T_60e16_row0_col14" class="data row0 col14" >2877187</td>
#       <td id="T_60e16_row0_col15" class="data row0 col15" >1473130</td>
#       <td id="T_60e16_row0_col16" class="data row0 col16" >210365</td>
#       <td id="T_60e16_row0_col17" class="data row0 col17" >97436</td>
#       <td id="T_60e16_row0_col18" class="data row0 col18" >1621026</td>
#       <td id="T_60e16_row0_col19" class="data row0 col19" >44949055</td>
#     </tr>
#     <tr>
#       <th id="T_60e16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60e16_row1_col0" class="data row1 col0" >    25 - 39</td>
#       <td id="T_60e16_row1_col1" class="data row1 col1" >75625156</td>
#       <td id="T_60e16_row1_col2" class="data row1 col2" >49401376</td>
#       <td id="T_60e16_row1_col3" class="data row1 col3" >16662003</td>
#       <td id="T_60e16_row1_col4" class="data row1 col4" >6736827</td>
#       <td id="T_60e16_row1_col5" class="data row1 col5" >1423693</td>
#       <td id="T_60e16_row1_col6" class="data row1 col6" >1401257</td>
#       <td id="T_60e16_row1_col7" class="data row1 col7" >65230956</td>
#       <td id="T_60e16_row1_col8" class="data row1 col8" >35997802</td>
#       <td id="T_60e16_row1_col9" class="data row1 col9" >11383198</td>
#       <td id="T_60e16_row1_col10" class="data row1 col10" >4979996</td>
#       <td id="T_60e16_row1_col11" class="data row1 col11" >1190071</td>
#       <td id="T_60e16_row1_col12" class="data row1 col12" >11679888</td>
#       <td id="T_60e16_row1_col13" class="data row1 col13" >34095607</td>
#       <td id="T_60e16_row1_col14" class="data row1 col14" >14059911</td>
#       <td id="T_60e16_row1_col15" class="data row1 col15" >9074660</td>
#       <td id="T_60e16_row1_col16" class="data row1 col16" >3061004</td>
#       <td id="T_60e16_row1_col17" class="data row1 col17" >1075926</td>
#       <td id="T_60e16_row1_col18" class="data row1 col18" >6824106</td>
#       <td id="T_60e16_row1_col19" class="data row1 col19" >174951719</td>
#     </tr>
#     <tr>
#       <th id="T_60e16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60e16_row2_col0" class="data row2 col0" >    40 - 54</td>
#       <td id="T_60e16_row2_col1" class="data row2 col1" >63304137</td>
#       <td id="T_60e16_row2_col2" class="data row2 col2" >43434586</td>
#       <td id="T_60e16_row2_col3" class="data row2 col3" >12751205</td>
#       <td id="T_60e16_row2_col4" class="data row2 col4" >4662314</td>
#       <td id="T_60e16_row2_col5" class="data row2 col5" >1464483</td>
#       <td id="T_60e16_row2_col6" class="data row2 col6" >991549</td>
#       <td id="T_60e16_row2_col7" class="data row2 col7" >63471403</td>
#       <td id="T_60e16_row2_col8" class="data row2 col8" >36427026</td>
#       <td id="T_60e16_row2_col9" class="data row2 col9" >11471318</td>
#       <td id="T_60e16_row2_col10" class="data row2 col10" >4762734</td>
#       <td id="T_60e16_row2_col11" class="data row2 col11" >1216737</td>
#       <td id="T_60e16_row2_col12" class="data row2 col12" >9593588</td>
#       <td id="T_60e16_row2_col13" class="data row2 col13" >36728444</td>
#       <td id="T_60e16_row2_col14" class="data row2 col14" >16923208</td>
#       <td id="T_60e16_row2_col15" class="data row2 col15" >8524321</td>
#       <td id="T_60e16_row2_col16" class="data row2 col16" >3760296</td>
#       <td id="T_60e16_row2_col17" class="data row2 col17" >1323949</td>
#       <td id="T_60e16_row2_col18" class="data row2 col18" >6196669</td>
#       <td id="T_60e16_row2_col19" class="data row2 col19" >163503984</td>
#     </tr>
#     <tr>
#       <th id="T_60e16_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60e16_row3_col0" class="data row3 col0" >    55 - 64</td>
#       <td id="T_60e16_row3_col1" class="data row3 col1" >43409325</td>
#       <td id="T_60e16_row3_col2" class="data row3 col2" >31263842</td>
#       <td id="T_60e16_row3_col3" class="data row3 col3" >8293475</td>
#       <td id="T_60e16_row3_col4" class="data row3 col4" >2410319</td>
#       <td id="T_60e16_row3_col5" class="data row3 col5" >826879</td>
#       <td id="T_60e16_row3_col6" class="data row3 col6" >614810</td>
#       <td id="T_60e16_row3_col7" class="data row3 col7" >42533760</td>
#       <td id="T_60e16_row3_col8" class="data row3 col8" >26711466</td>
#       <td id="T_60e16_row3_col9" class="data row3 col9" >7157102</td>
#       <td id="T_60e16_row3_col10" class="data row3 col10" >2222868</td>
#       <td id="T_60e16_row3_col11" class="data row3 col11" >486280</td>
#       <td id="T_60e16_row3_col12" class="data row3 col12" >5956044</td>
#       <td id="T_60e16_row3_col13" class="data row3 col13" >9213268</td>
#       <td id="T_60e16_row3_col14" class="data row3 col14" >3904435</td>
#       <td id="T_60e16_row3_col15" class="data row3 col15" >2118566</td>
#       <td id="T_60e16_row3_col16" class="data row3 col16" >829202</td>
#       <td id="T_60e16_row3_col17" class="data row3 col17" >321591</td>
#       <td id="T_60e16_row3_col18" class="data row3 col18"

# %%
# copying EDUCATION characteristics from df1 to new dataframe
df_education = pd.concat([df1.iloc[13:17].reset_index(drop=True), df2nohead.iloc[13:17].reset_index(drop=True), df3nohead.iloc[13:17].reset_index(drop=True)], axis=1)
df_education["total"] = df_education["1_total"] + df_education["2_total"] + df_education["3_total"]

df_education.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_34ad2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ad2_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_34ad2_level0_col1" class="col_heading level0 col1" >1_total</th>
#       <th id="T_34ad2_level0_col2" class="col_heading level0 col2" >1_enough_and_all_food</th>
#       <th id="T_34ad2_level0_col3" class="col_heading level0 col3" >1_enough_and_some_food</th>
#       <th id="T_34ad2_level0_col4" class="col_heading level0 col4" >1_sometimes_not_enough</th>
#       <th id="T_34ad2_level0_col5" class="col_heading level0 col5" >1_often_not_enough</th>
#       <th id="T_34ad2_level0_col6" class="col_heading level0 col6" >1_did_no_report</th>
#       <th id="T_34ad2_level0_col7" class="col_heading level0 col7" >2_total</th>
#       <th id="T_34ad2_level0_col8" class="col_heading level0 col8" >2_enough_and_all_food</th>
#       <th id="T_34ad2_level0_col9" class="col_heading level0 col9" >2_enough_and_some_food</th>
#       <th id="T_34ad2_level0_col10" class="col_heading level0 col10" >2_sometimes_not_enough</th>
#       <th id="T_34ad2_level0_col11" class="col_heading level0 col11" >2_often_not_enough</th>
#       <th id="T_34ad2_level0_col12" class="col_heading level0 col12" >2_did_no_report</th>
#       <th id="T_34ad2_level0_col13" class="col_heading level0 col13" >3_total</th>
#       <th id="T_34ad2_level0_col14" class="col_heading level0 col14" >3_enough_and_all_food</th>
#       <th id="T_34ad2_level0_col15" class="col_heading level0 col15" >3_enough_and_some_food</th>
#       <th id="T_34ad2_level0_col16" class="col_heading level0 col16" >3_sometimes_not_enough</th>
#       <th id="T_34ad2_level0_col17" class="col_heading level0 col17" >3_often_not_enough</th>
#       <th id="T_34ad2_level0_col18" class="col_heading level0 col18" >3_did_no_report</th>
#       <th id="T_34ad2_level0_col19" class="col_heading level0 col19" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ad2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34ad2_row0_col0" class="data row0 col0" >    Less than high school</td>
#       <td id="T_34ad2_row0_col1" class="data row0 col1" >17668871</td>
#       <td id="T_34ad2_row0_col2" class="data row0 col2" >8616307</td>
#       <td id="T_34ad2_row0_col3" class="data row0 col3" >4471575</td>
#       <td id="T_34ad2_row0_col4" class="data row0 col4" >2974455</td>
#       <td id="T_34ad2_row0_col5" class="data row0 col5" >1036608</td>
#       <td id="T_34ad2_row0_col6" class="data row0 col6" >569925</td>
#       <td id="T_34ad2_row0_col7" class="data row0 col7" >20156177</td>
#       <td id="T_34ad2_row0_col8" class="data row0 col8" >7429472</td>
#       <td id="T_34ad2_row0_col9" class="data row0 col9" >4370675</td>
#       <td id="T_34ad2_row0_col10" class="data row0 col10" >2471776</td>
#       <td id="T_34ad2_row0_col11" class="data row0 col11" >1006740</td>
#       <td id="T_34ad2_row0_col12" class="data row0 col12" >4877513</td>
#       <td id="T_34ad2_row0_col13" class="data row0 col13" >10604385</td>
#       <td id="T_34ad2_row0_col14" class="data row0 col14" >2657651</td>
#       <td id="T_34ad2_row0_col15" class="data row0 col15" >2543181</td>
#       <td id="T_34ad2_row0_col16" class="data row0 col16" >1473654</td>
#       <td id="T_34ad2_row0_col17" class="data row0 col17" >870810</td>
#       <td id="T_34ad2_row0_col18" class="data row0 col18" >3059089</td>
#       <td id="T_34ad2_row0_col19" class="data row0 col19" >48429433</td>
#     </tr>
#     <tr>
#       <th id="T_34ad2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34ad2_row1_col0" class="data row1 col0" >    High school or GED</td>
#       <td id="T_34ad2_row1_col1" class="data row1 col1" >79924953</td>
#       <td id="T_34ad2_row1_col2" class="data row1 col2" >52216407</td>
#       <td id="T_34ad2_row1_col3" class="data row1 col3" >18028065</td>
#       <td id="T_34ad2_row1_col4" class="data row1 col4" >6481271</td>
#       <td id="T_34ad2_row1_col5" class="data row1 col5" >1693632</td>
#       <td id="T_34ad2_row1_col6" class="data row1 col6" >1505579</td>
#       <td id="T_34ad2_row1_col7" class="data row1 col7" >77288442</td>
#       <td id="T_34ad2_row1_col8" class="data row1 col8" >40721363</td>
#       <td id="T_34ad2_row1_col9" class="data row1 col9" >13942126</td>
#       <td id="T_34ad2_row1_col10" class="data row1 col10" >6139767</td>
#       <td id="T_34ad2_row1_col11" class="data row1 col11" >1108752</td>
#       <td id="T_34ad2_row1_col12" class="data row1 col12" >15376434</td>
#       <td id="T_34ad2_row1_col13" class="data row1 col13" >28880584</td>
#       <td id="T_34ad2_row1_col14" class="data row1 col14" >9668542</td>
#       <td id="T_34ad2_row1_col15" class="data row1 col15" >7593000</td>
#       <td id="T_34ad2_row1_col16" class="data row1 col16" >3366956</td>
#       <td id="T_34ad2_row1_col17" class="data row1 col17" >1259603</td>
#       <td id="T_34ad2_row1_col18" class="data row1 col18" >6992484</td>
#       <td id="T_34ad2_row1_col19" class="data row1 col19" >186093979</td>
#     </tr>
#     <tr>
#       <th id="T_34ad2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34ad2_row2_col0" class="data row2 col0" >    Some college/associate’s degree</td>
#       <td id="T_34ad2_row2_col1" class="data row2 col1" >75928558</td>
#       <td id="T_34ad2_row2_col2" class="data row2 col2" >51987591</td>
#       <td id="T_34ad2_row2_col3" class="data row2 col3" >16630293</td>
#       <td id="T_34ad2_row2_col4" class="data row2 col4" >5106711</td>
#       <td id="T_34ad2_row2_col5" class="data row2 col5" >1153124</td>
#       <td id="T_34ad2_row2_col6" class="data row2 col6" >1050840</td>
#       <td id="T_34ad2_row2_col7" class="data row2 col7" >75567240</td>
#       <td id="T_34ad2_row2_col8" class="data row2 col8" >42849643</td>
#       <td id="T_34ad2_row2_col9" class="data row2 col9" >14696746</td>
#       <td id="T_34ad2_row2_col10" class="data row2 col10" >4576649</td>
#       <td id="T_34ad2_row2_col11" class="data row2 col11" >996434</td>
#       <td id="T_34ad2_row2_col12" class="data row2 col12" >12447768</td>
#       <td id="T_34ad2_row2_col13" class="data row2 col13" >27975220</td>
#       <td id="T_34ad2_row2_col14" class="data row2 col14" >11286649</td>
#       <td id="T_34ad2_row2_col15" class="data row2 col15" >8082298</td>
#       <td id="T_34ad2_row2_col16" class="data row2 col16" >2852244</td>
#       <td id="T_34ad2_row2_col17" class="data row2 col17" >783014</td>
#       <td id="T_34ad2_row2_col18" class="data row2 col18" >4971016</td>
#       <td id="T_34ad2_row2_col19" class="data row2 col19" >179471018</td>
#     </tr>
#     <tr>
#       <th id="T_34ad2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34ad2_row3_col0" class="data row3 col0" >    Bachelor’s degree or higher</td>
#       <td id="T_34ad2_row3_col1" class="data row3 col1" >75648533</td>
#       <td id="T_34ad2_row3_col2" class="data row3 col2" >62719440</td>
#       <td id="T_34ad2_row3_col3" class="data row3 col3" >10275216</td>
#       <td id="T_34ad2_row3_col4" class="data row3 col4" >1284026</td>
#       <td id="T_34ad2_row3_col5" class="data row3 col5" >326764</td>
#       <td id="T_34ad2_row3_col6" class="data row3 col6" >1043088</td>
#       <td id="T_34ad2_row3_col7" class="data row3 col7" >77253590</td>
#       <td id="T_34ad2_row3_col8" class="data row3 col8" >57971115</td>
#       <td id="T_34ad2_row3_col9" class="data row3 col9" >8693924</td>
#       <td id="T_34ad2_row3_col10" class="data row3 col10" >1426322</td>
#       <td id="T_34ad2_row3_col11" class="data row3 col11" >470944</td>
#       <td id="T_34ad2_row3_col12" class="data row3 col12" >8691286</td>
#       <td id="T_34ad2_row3_col13" class="data row3 col13" >27295691</td>
#       <td id="T_34ad2_row3_col14" class="data row3 col14" >18526696</td>
#       <td id="T_34ad2_row3_col15" class="data row3 col15" >4671874</td>
#       <td id="T_34ad2_row3_col16" class="data row3 col16" >726307</td>
#       <td id="T_34ad2_row3_col17" class="data row3 c

# %%
# copying INCOME characteristics from previous dfs to new dataframe
df_income = pd.concat([df1.iloc[48:57].reset_index(drop=True), df2nohead.iloc[50:59].reset_index(drop=True), df3nohead.iloc[45:54].reset_index(drop=True)], axis=1)
df_income["total"] = df_income["1_total"] + df_income["2_total"] + df_income["3_total"]

df_income.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7f75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7f75_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_c7f75_level0_col1" class="col_heading level0 col1" >1_total</th>
#       <th id="T_c7f75_level0_col2" class="col_heading level0 col2" >1_enough_and_all_food</th>
#       <th id="T_c7f75_level0_col3" class="col_heading level0 col3" >1_enough_and_some_food</th>
#       <th id="T_c7f75_level0_col4" class="col_heading level0 col4" >1_sometimes_not_enough</th>
#       <th id="T_c7f75_level0_col5" class="col_heading level0 col5" >1_often_not_enough</th>
#       <th id="T_c7f75_level0_col6" class="col_heading level0 col6" >1_did_no_report</th>
#       <th id="T_c7f75_level0_col7" class="col_heading level0 col7" >2_total</th>
#       <th id="T_c7f75_level0_col8" class="col_heading level0 col8" >2_enough_and_all_food</th>
#       <th id="T_c7f75_level0_col9" class="col_heading level0 col9" >2_enough_and_some_food</th>
#       <th id="T_c7f75_level0_col10" class="col_heading level0 col10" >2_sometimes_not_enough</th>
#       <th id="T_c7f75_level0_col11" class="col_heading level0 col11" >2_often_not_enough</th>
#       <th id="T_c7f75_level0_col12" class="col_heading level0 col12" >2_did_no_report</th>
#       <th id="T_c7f75_level0_col13" class="col_heading level0 col13" >3_total</th>
#       <th id="T_c7f75_level0_col14" class="col_heading level0 col14" >3_enough_and_all_food</th>
#       <th id="T_c7f75_level0_col15" class="col_heading level0 col15" >3_enough_and_some_food</th>
#       <th id="T_c7f75_level0_col16" class="col_heading level0 col16" >3_sometimes_not_enough</th>
#       <th id="T_c7f75_level0_col17" class="col_heading level0 col17" >3_often_not_enough</th>
#       <th id="T_c7f75_level0_col18" class="col_heading level0 col18" >3_did_no_report</th>
#       <th id="T_c7f75_level0_col19" class="col_heading level0 col19" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7f75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7f75_row0_col0" class="data row0 col0" >    Less than $25,000</td>
#       <td id="T_c7f75_row0_col1" class="data row0 col1" >34828279</td>
#       <td id="T_c7f75_row0_col2" class="data row0 col2" >17133827</td>
#       <td id="T_c7f75_row0_col3" class="data row0 col3" >9618035</td>
#       <td id="T_c7f75_row0_col4" class="data row0 col4" >5901334</td>
#       <td id="T_c7f75_row0_col5" class="data row0 col5" >2047932</td>
#       <td id="T_c7f75_row0_col6" class="data row0 col6" >127151</td>
#       <td id="T_c7f75_row0_col7" class="data row0 col7" >23732207</td>
#       <td id="T_c7f75_row0_col8" class="data row0 col8" >10515340</td>
#       <td id="T_c7f75_row0_col9" class="data row0 col9" >7528310</td>
#       <td id="T_c7f75_row0_col10" class="data row0 col10" >4389243</td>
#       <td id="T_c7f75_row0_col11" class="data row0 col11" >1223597</td>
#       <td id="T_c7f75_row0_col12" class="data row0 col12" >75718</td>
#       <td id="T_c7f75_row0_col13" class="data row0 col13" >9821007</td>
#       <td id="T_c7f75_row0_col14" class="data row0 col14" >3139303</td>
#       <td id="T_c7f75_row0_col15" class="data row0 col15" >3258009</td>
#       <td id="T_c7f75_row0_col16" class="data row0 col16" >2226079</td>
#       <td id="T_c7f75_row0_col17" class="data row0 col17" >1153678</td>
#       <td id="T_c7f75_row0_col18" class="data row0 col18" >43937</td>
#       <td id="T_c7f75_row0_col19" class="data row0 col19" >68381493</td>
#     </tr>
#     <tr>
#       <th id="T_c7f75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7f75_row1_col0" class="data row1 col0" >    $25,000 - $34,999</td>
#       <td id="T_c7f75_row1_col1" class="data row1 col1" >25707367</td>
#       <td id="T_c7f75_row1_col2" class="data row1 col2" >15549522</td>
#       <td id="T_c7f75_row1_col3" class="data row1 col3" >6592797</td>
#       <td id="T_c7f75_row1_col4" class="data row1 col4" >3018351</td>
#       <td id="T_c7f75_row1_col5" class="data row1 col5" >507339</td>
#       <td id="T_c7f75_row1_col6" class="data row1 col6" >39359</td>
#       <td id="T_c7f75_row1_col7" class="data row1 col7" >18636048</td>
#       <td id="T_c7f75_row1_col8" class="data row1 col8" >10043422</td>
#       <td id="T_c7f75_row1_col9" class="data row1 col9" >5433349</td>
#       <td id="T_c7f75_row1_col10" class="data row1 col10" >2487504</td>
#       <td id="T_c7f75_row1_col11" class="data row1 col11" >562012</td>
#       <td id="T_c7f75_row1_col12" class="data row1 col12" >109760</td>
#       <td id="T_c7f75_row1_col13" class="data row1 col13" >6872228</td>
#       <td id="T_c7f75_row1_col14" class="data row1 col14" >2251581</td>
#       <td id="T_c7f75_row1_col15" class="data row1 col15" >2530206</td>
#       <td id="T_c7f75_row1_col16" class="data row1 col16" >1584736</td>
#       <td id="T_c7f75_row1_col17" class="data row1 col17" >467650</td>
#       <td id="T_c7f75_row1_col18" class="data row1 col18" >38053</td>
#       <td id="T_c7f75_row1_col19" class="data row1 col19" >51215643</td>
#     </tr>
#     <tr>
#       <th id="T_c7f75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7f75_row2_col0" class="data row2 col0" >    $35,000 - $49,999</td>
#       <td id="T_c7f75_row2_col1" class="data row2 col1" >27626364</td>
#       <td id="T_c7f75_row2_col2" class="data row2 col2" >19073450</td>
#       <td id="T_c7f75_row2_col3" class="data row2 col3" >6373823</td>
#       <td id="T_c7f75_row2_col4" class="data row2 col4" >1726076</td>
#       <td id="T_c7f75_row2_col5" class="data row2 col5" >386555</td>
#       <td id="T_c7f75_row2_col6" class="data row2 col6" >66460</td>
#       <td id="T_c7f75_row2_col7" class="data row2 col7" >20811511</td>
#       <td id="T_c7f75_row2_col8" class="data row2 col8" >13141059</td>
#       <td id="T_c7f75_row2_col9" class="data row2 col9" >5535377</td>
#       <td id="T_c7f75_row2_col10" class="data row2 col10" >1860203</td>
#       <td id="T_c7f75_row2_col11" class="data row2 col11" >263995</td>
#       <td id="T_c7f75_row2_col12" class="data row2 col12" >10877</td>
#       <td id="T_c7f75_row2_col13" class="data row2 col13" >6940358</td>
#       <td id="T_c7f75_row2_col14" class="data row2 col14" >3004175</td>
#       <td id="T_c7f75_row2_col15" class="data row2 col15" >2768503</td>
#       <td id="T_c7f75_row2_col16" class="data row2 col16" >943357</td>
#       <td id="T_c7f75_row2_col17" class="data row2 col17" >197963</td>
#       <td id="T_c7f75_row2_col18" class="data row2 col18" >26360</td>
#       <td id="T_c7f75_row2_col19" class="data row2 col19" >55378233</td>
#     </tr>
#     <tr>
#       <th id="T_c7f75_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7f75_row3_col0" class="data row3 col0" >    $50,000 - $74,999</td>
#       <td id="T_c7f75_row3_col1" class="data row3 col1" >38956223</td>
#       <td id="T_c7f75_row3_col2" class="data row3 col2" >28724977</td>
#       <td id="T_c7f75_row3_col3" class="data row3 col3" >8181219</td>
#       <td id="T_c7f75_row3_col4" class="data row3 col4" >1607013</td>
#       <td id="T_c7f75_row3_col5" class="data row3 col5" >387326</td>
#       <td id="T_c7f75_row3_col6" class="data row3 col6" >55689</td>
#       <td id="T_c7f75_row3_col7" class="data row3 col7" >28507113</td>
#       <td id="T_c7f75_row3_col8" class="data row3 col8" >21090818</td>
#       <td id="T_c7f75_row3_col9" class="data row3 col9" >5909950</td>
#       <td id="T_c7f75_row3_col10" class="data row3 col10" >1311151</td>
#       <td id="T_c7f75_row3_col11" class="data row3 col11" >176337</td>
#       <td id="T_c7f75_row3_col12" class="data row3 col12" >18856</td>
#       <td id="T_c7f75_row3_col13" class="data row3 col13" >10774268</td>
#       <td id="T_c7f75_row3_col14" class="data row3 col14" >4900427</td>
#       <td id="T_c7f75_row3_col15" class="data row3 col15" >4327836</td>
#       <td id="T_c7f75_row3_col16" class="data row3 col16" >1070975</td>
#       <td id="T_c7f75_row3_col17" class="data row3 col17" >383024</td>
#       <td id="T_c7f75_row3_col18" class="dat

# %%
# copying UNEMPLOYMENT characteristics from previous dfs to new dataframe
df_unemployment = pd.concat([df1.iloc[30:43].reset_index(drop=True), df2nohead.iloc[37:50].reset_index(drop=True), df3nohead.iloc[32:45].reset_index(drop=True)], axis=1)
df_unemployment["total"] = df_unemployment["1_total"] + df_unemployment["2_total"] + df_unemployment["3_total"]

df_unemployment.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb498" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb498_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_bb498_level0_col1" class="col_heading level0 col1" >1_total</th>
#       <th id="T_bb498_level0_col2" class="col_heading level0 col2" >1_enough_and_all_food</th>
#       <th id="T_bb498_level0_col3" class="col_heading level0 col3" >1_enough_and_some_food</th>
#       <th id="T_bb498_level0_col4" class="col_heading level0 col4" >1_sometimes_not_enough</th>
#       <th id="T_bb498_level0_col5" class="col_heading level0 col5" >1_often_not_enough</th>
#       <th id="T_bb498_level0_col6" class="col_heading level0 col6" >1_did_no_report</th>
#       <th id="T_bb498_level0_col7" class="col_heading level0 col7" >2_total</th>
#       <th id="T_bb498_level0_col8" class="col_heading level0 col8" >2_enough_and_all_food</th>
#       <th id="T_bb498_level0_col9" class="col_heading level0 col9" >2_enough_and_some_food</th>
#       <th id="T_bb498_level0_col10" class="col_heading level0 col10" >2_sometimes_not_enough</th>
#       <th id="T_bb498_level0_col11" class="col_heading level0 col11" >2_often_not_enough</th>
#       <th id="T_bb498_level0_col12" class="col_heading level0 col12" >2_did_no_report</th>
#       <th id="T_bb498_level0_col13" class="col_heading level0 col13" >3_total</th>
#       <th id="T_bb498_level0_col14" class="col_heading level0 col14" >3_enough_and_all_food</th>
#       <th id="T_bb498_level0_col15" class="col_heading level0 col15" >3_enough_and_some_food</th>
#       <th id="T_bb498_level0_col16" class="col_heading level0 col16" >3_sometimes_not_enough</th>
#       <th id="T_bb498_level0_col17" class="col_heading level0 col17" >3_often_not_enough</th>
#       <th id="T_bb498_level0_col18" class="col_heading level0 col18" >3_did_no_report</th>
#       <th id="T_bb498_level0_col19" class="col_heading level0 col19" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb498_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb498_row0_col0" class="data row0 col0" >    Did not want to be employed</td>
#       <td id="T_bb498_row0_col1" class="data row0 col1" >3803792</td>
#       <td id="T_bb498_row0_col2" class="data row0 col2" >2932446</td>
#       <td id="T_bb498_row0_col3" class="data row0 col3" >574895</td>
#       <td id="T_bb498_row0_col4" class="data row0 col4" >218582</td>
#       <td id="T_bb498_row0_col5" class="data row0 col5" >1221</td>
#       <td id="T_bb498_row0_col6" class="data row0 col6" >76648</td>
#       <td id="T_bb498_row0_col7" class="data row0 col7" >5790358</td>
#       <td id="T_bb498_row0_col8" class="data row0 col8" >3390714</td>
#       <td id="T_bb498_row0_col9" class="data row0 col9" >525071</td>
#       <td id="T_bb498_row0_col10" class="data row0 col10" >126789</td>
#       <td id="T_bb498_row0_col11" class="data row0 col11" >219323</td>
#       <td id="T_bb498_row0_col12" class="data row0 col12" >1528462</td>
#       <td id="T_bb498_row0_col13" class="data row0 col13" >2093774</td>
#       <td id="T_bb498_row0_col14" class="data row0 col14" >965486</td>
#       <td id="T_bb498_row0_col15" class="data row0 col15" >342980</td>
#       <td id="T_bb498_row0_col16" class="data row0 col16" >95319</td>
#       <td id="T_bb498_row0_col17" class="data row0 col17" >38496</td>
#       <td id="T_bb498_row0_col18" class="data row0 col18" >651492</td>
#       <td id="T_bb498_row0_col19" class="data row0 col19" >11687924</td>
#     </tr>
#     <tr>
#       <th id="T_bb498_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb498_row1_col0" class="data row1 col0" >    Sick with coronavirus symptoms</td>
#       <td id="T_bb498_row1_col1" class="data row1 col1" >1109969</td>
#       <td id="T_bb498_row1_col2" class="data row1 col2" >524792</td>
#       <td id="T_bb498_row1_col3" class="data row1 col3" >315649</td>
#       <td id="T_bb498_row1_col4" class="data row1 col4" >138154</td>
#       <td id="T_bb498_row1_col5" class="data row1 col5" >127722</td>
#       <td id="T_bb498_row1_col6" class="data row1 col6" >3652</td>
#       <td id="T_bb498_row1_col7" class="data row1 col7" >2140725</td>
#       <td id="T_bb498_row1_col8" class="data row1 col8" >596391</td>
#       <td id="T_bb498_row1_col9" class="data row1 col9" >640710</td>
#       <td id="T_bb498_row1_col10" class="data row1 col10" >327313</td>
#       <td id="T_bb498_row1_col11" class="data row1 col11" >153254</td>
#       <td id="T_bb498_row1_col12" class="data row1 col12" >423058</td>
#       <td id="T_bb498_row1_col13" class="data row1 col13" >1512168</td>
#       <td id="T_bb498_row1_col14" class="data row1 col14" >280455</td>
#       <td id="T_bb498_row1_col15" class="data row1 col15" >358229</td>
#       <td id="T_bb498_row1_col16" class="data row1 col16" >363542</td>
#       <td id="T_bb498_row1_col17" class="data row1 col17" >183737</td>
#       <td id="T_bb498_row1_col18" class="data row1 col18" >326205</td>
#       <td id="T_bb498_row1_col19" class="data row1 col19" >4762862</td>
#     </tr>
#     <tr>
#       <th id="T_bb498_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb498_row2_col0" class="data row2 col0" >    Caring for someone with coronavirus symptoms</td>
#       <td id="T_bb498_row2_col1" class="data row2 col1" >204333</td>
#       <td id="T_bb498_row2_col2" class="data row2 col2" >87112</td>
#       <td id="T_bb498_row2_col3" class="data row2 col3" >22563</td>
#       <td id="T_bb498_row2_col4" class="data row2 col4" >86191</td>
#       <td id="T_bb498_row2_col5" class="data row2 col5" >5469</td>
#       <td id="T_bb498_row2_col6" class="data row2 col6" >2997</td>
#       <td id="T_bb498_row2_col7" class="data row2 col7" >6894328</td>
#       <td id="T_bb498_row2_col8" class="data row2 col8" >2851336</td>
#       <td id="T_bb498_row2_col9" class="data row2 col9" >1583119</td>
#       <td id="T_bb498_row2_col10" class="data row2 col10" >770918</td>
#       <td id="T_bb498_row2_col11" class="data row2 col11" >167030</td>
#       <td id="T_bb498_row2_col12" class="data row2 col12" >1521925</td>
#       <td id="T_bb498_row2_col13" class="data row2 col13" >4383954</td>
#       <td id="T_bb498_row2_col14" class="data row2 col14" >1673914</td>
#       <td id="T_bb498_row2_col15" class="data row2 col15" >1556636</td>
#       <td id="T_bb498_row2_col16" class="data row2 col16" >602220</td>
#       <td id="T_bb498_row2_col17" class="data row2 col17" >50849</td>
#       <td id="T_bb498_row2_col18" class="data row2 col18" >500336</td>
#       <td id="T_bb498_row2_col19" class="data row2 col19" >11482615</td>
#     </tr>
#     <tr>
#       <th id="T_bb498_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb498_row3_col0" class="data row3 col0" >    Caring for children not in school or daycare</td>
#       <td id="T_bb498_row3_col1" class="data row3 col1" >5994569</td>
#       <td id="T_bb498_row3_col2" class="data row3 col2" >3267210</td>
#       <td id="T_bb498_row3_col3" class="data row3 col3" >1571995</td>
#       <td id="T_bb498_row3_col4" class="data row3 col4" >996563</td>
#       <td id="T_bb498_row3_col5" class="data row3 col5" >79770</td>
#       <td id="T_bb498_row3_col6" class="data row3 col6" >79031</td>
#       <td id="T_bb498_row3_col7" class="data row3 col7" >2455616</td>
#       <td id="T_bb498_row3_col8" class="data row3 col8" >1025344</td>
#       <td id="T_bb498_row3_col9" class="data row3 col9" >593293</td>
#       <td id="T_bb498_row3_col10" class="data row3 col10" >360620</td>
#       <td id="T_bb498_row3_col11" class="data row3 col11" >69773</td>
#       <td id="T_bb498_row3_col12" class="data row3 col12" >406586</td>
#       <td id="T_bb498_row3_col13" class="data row3 col13" >848280</td>
#       <td id="T_bb498_row3_col14" class="data row3 col14" >202682</td>
#       <td id="T_bb498_row3_col15" class="data row3 col15" >105137</td>
#       <td id="T_bb498_row3_col16" class="data row3 col16" >111533</td>
#       <td id="T_bb498_row3_col17" class="data row3 col17" >266914</td>
#       <td id="T_bb498_r

# %%
# copying ANXIETY characteristics from previous dfs to new dataframe
df_anxiety = pd.concat([df1.iloc[63:68].reset_index(drop=True), df2nohead.iloc[71:76].reset_index(drop=True), df3nohead.iloc[69:73].reset_index(drop=True)], axis=1)
df_anxiety["total"] = df_anxiety["1_total"] + df_anxiety["2_total"] + df_anxiety["3_total"]

df_anxiety.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3887" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3887_level0_col0" class="col_heading level0 col0" >Select Characteristics</th>
#       <th id="T_a3887_level0_col1" class="col_heading level0 col1" >1_total</th>
#       <th id="T_a3887_level0_col2" class="col_heading level0 col2" >1_enough_and_all_food</th>
#       <th id="T_a3887_level0_col3" class="col_heading level0 col3" >1_enough_and_some_food</th>
#       <th id="T_a3887_level0_col4" class="col_heading level0 col4" >1_sometimes_not_enough</th>
#       <th id="T_a3887_level0_col5" class="col_heading level0 col5" >1_often_not_enough</th>
#       <th id="T_a3887_level0_col6" class="col_heading level0 col6" >1_did_no_report</th>
#       <th id="T_a3887_level0_col7" class="col_heading level0 col7" >2_total</th>
#       <th id="T_a3887_level0_col8" class="col_heading level0 col8" >2_enough_and_all_food</th>
#       <th id="T_a3887_level0_col9" class="col_heading level0 col9" >2_enough_and_some_food</th>
#       <th id="T_a3887_level0_col10" class="col_heading level0 col10" >2_sometimes_not_enough</th>
#       <th id="T_a3887_level0_col11" class="col_heading level0 col11" >2_often_not_enough</th>
#       <th id="T_a3887_level0_col12" class="col_heading level0 col12" >2_did_no_report</th>
#       <th id="T_a3887_level0_col13" class="col_heading level0 col13" >3_total</th>
#       <th id="T_a3887_level0_col14" class="col_heading level0 col14" >3_enough_and_all_food</th>
#       <th id="T_a3887_level0_col15" class="col_heading level0 col15" >3_enough_and_some_food</th>
#       <th id="T_a3887_level0_col16" class="col_heading level0 col16" >3_sometimes_not_enough</th>
#       <th id="T_a3887_level0_col17" class="col_heading level0 col17" >3_often_not_enough</th>
#       <th id="T_a3887_level0_col18" class="col_heading level0 col18" >3_did_no_report</th>
#       <th id="T_a3887_level0_col19" class="col_heading level0 col19" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3887_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3887_row0_col0" class="data row0 col0" >    Not at all</td>
#       <td id="T_a3887_row0_col1" class="data row0 col1" >81563348</td>
#       <td id="T_a3887_row0_col2" class="data row0 col2" >66771810</td>
#       <td id="T_a3887_row0_col3" class="data row0 col3" >11182988</td>
#       <td id="T_a3887_row0_col4" class="data row0 col4" >2847778</td>
#       <td id="T_a3887_row0_col5" class="data row0 col5" >611301</td>
#       <td id="T_a3887_row0_col6" class="data row0 col6" >149471</td>
#       <td id="T_a3887_row0_col7" class="data row0 col7" >102929917</td>
#       <td id="T_a3887_row0_col8" class="data row0 col8" >87714045</td>
#       <td id="T_a3887_row0_col9" class="data row0 col9" >11711125</td>
#       <td id="T_a3887_row0_col10" class="data row0 col10" >2872833</td>
#       <td id="T_a3887_row0_col11" class="data row0 col11" >465319</td>
#       <td id="T_a3887_row0_col12" class="data row0 col12" >166594</td>
#       <td id="T_a3887_row0_col13" class="data row0 col13" >28968051</td>
#       <td id="T_a3887_row0_col14" class="data row0 col14" >20545015</td>
#       <td id="T_a3887_row0_col15" class="data row0 col15" >5734544</td>
#       <td id="T_a3887_row0_col16" class="data row0 col16" >1696963</td>
#       <td id="T_a3887_row0_col17" class="data row0 col17" >697166</td>
#       <td id="T_a3887_row0_col18" class="data row0 col18" >294363</td>
#       <td id="T_a3887_row0_col19" class="data row0 col19" >213461316</td>
#     </tr>
#     <tr>
#       <th id="T_a3887_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3887_row1_col0" class="data row1 col0" >    Several days</td>
#       <td id="T_a3887_row1_col1" class="data row1 col1" >77079809</td>
#       <td id="T_a3887_row1_col2" class="data row1 col2" >55593346</td>
#       <td id="T_a3887_row1_col3" class="data row1 col3" >16393208</td>
#       <td id="T_a3887_row1_col4" class="data row1 col4" >4124650</td>
#       <td id="T_a3887_row1_col5" class="data row1 col5" >823683</td>
#       <td id="T_a3887_row1_col6" class="data row1 col6" >144921</td>
#       <td id="T_a3887_row1_col7" class="data row1 col7" >49897598</td>
#       <td id="T_a3887_row1_col8" class="data row1 col8" >32024124</td>
#       <td id="T_a3887_row1_col9" class="data row1 col9" >13411922</td>
#       <td id="T_a3887_row1_col10" class="data row1 col10" >3916892</td>
#       <td id="T_a3887_row1_col11" class="data row1 col11" >449096</td>
#       <td id="T_a3887_row1_col12" class="data row1 col12" >95563</td>
#       <td id="T_a3887_row1_col13" class="data row1 col13" >24268703</td>
#       <td id="T_a3887_row1_col14" class="data row1 col14" >13321259</td>
#       <td id="T_a3887_row1_col15" class="data row1 col15" >8019108</td>
#       <td id="T_a3887_row1_col16" class="data row1 col16" >2658769</td>
#       <td id="T_a3887_row1_col17" class="data row1 col17" >199006</td>
#       <td id="T_a3887_row1_col18" class="data row1 col18" >70561</td>
#       <td id="T_a3887_row1_col19" class="data row1 col19" >151246110</td>
#     </tr>
#     <tr>
#       <th id="T_a3887_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3887_row2_col0" class="data row2 col0" >    More than half the days</td>
#       <td id="T_a3887_row2_col1" class="data row2 col1" >30361230</td>
#       <td id="T_a3887_row2_col2" class="data row2 col2" >19167579</td>
#       <td id="T_a3887_row2_col3" class="data row2 col3" >7414110</td>
#       <td id="T_a3887_row2_col4" class="data row2 col4" >3170047</td>
#       <td id="T_a3887_row2_col5" class="data row2 col5" >545751</td>
#       <td id="T_a3887_row2_col6" class="data row2 col6" >63743</td>
#       <td id="T_a3887_row2_col7" class="data row2 col7" >18859692</td>
#       <td id="T_a3887_row2_col8" class="data row2 col8" >9164616</td>
#       <td id="T_a3887_row2_col9" class="data row2 col9" >6306887</td>
#       <td id="T_a3887_row2_col10" class="data row2 col10" >2758787</td>
#       <td id="T_a3887_row2_col11" class="data row2 col11" >611990</td>
#       <td id="T_a3887_row2_col12" class="data row2 col12" >17411</td>
#       <td id="T_a3887_row2_col13" class="data row2 col13" >7716324</td>
#       <td id="T_a3887_row2_col14" class="data row2 col14" >3132338</td>
#       <td id="T_a3887_row2_col15" class="data row2 col15" >2968198</td>
#       <td id="T_a3887_row2_col16" class="data row2 col16" >1227817</td>
#       <td id="T_a3887_row2_col17" class="data row2 col17" >383638</td>
#       <td id="T_a3887_row2_col18" class="data row2 col18" >4334</td>
#       <td id="T_a3887_row2_col19" class="data row2 col19" >56937246</td>
#     </tr>
#     <tr>
#       <th id="T_a3887_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3887_row3_col0" class="data row3 col0" >    Nearly every day</td>
#       <td id="T_a3887_row3_col1" class="data row3 col1" >36573868</td>
#       <td id="T_a3887_row3_col2" class="data row3 col2" >20953674</td>
#       <td id="T_a3887_row3_col3" class="data row3 col3" >9463244</td>
#       <td id="T_a3887_row3_col4" class="data row3 col4" >4234303</td>
#       <td id="T_a3887_row3_col5" class="data row3 col5" >1877909</td>
#       <td id="T_a3887_row3_col6" class="data row3 col6" >44738</td>
#       <td id="T_a3887_row3_col7" class="data row3 col7" >19088384</td>
#       <td id="T_a3887_row3_col8" class="data row3 col8" >7806297</td>
#       <td id="T_a3887_row3_col9" class="data row3 col9" >5844296</td>
#       <td id="T_a3887_row3_col10" class="data row3 col10" >3764796</td>
#       <td id="T_a3887_row3_col11" class="data row3 col11" >1640986</td>
#       <td id="T_a3887_row3_col12" class="data row3 col12" >32010</td>
#       <td id="T_a3887_row3_col13" class="data row3 col13" >12985219</td>
#       <td id="T_a3887_row3_col14" class="data row3 col14" >3996863</td>
#       <td id="T_a3887_row3_col15" class="data row3 col15" >4998912</td>
#       <td id="T_a3887_row3_col16" class="data row3 col16" >2268125</td>
#       <td id="T_a3887_row3_col17" class="data row3 col17" >1684143</td>
#       <td id="T_a3887_row3_col18" class=

# %%
import plotly.express as px
import plotly.io as pio

# creating plots that show the sub group break up of various characteristics
fig = px.pie(df_age, values='total', names='Select Characteristics', title = 'Breakdown of sample by age groups (2020-2022)')
fig.show()
fig2 = px.pie(df_unemployment, values='total', names='Select Characteristics', title = 'Breakdown of sample by unemployment type (2020-2022)')
fig2.show()
fig3 = px.pie(df_income, values='total', names='Select Characteristics', title = 'Breakdown of sample by income group (2020-2022)')
fig3.show()
fig4 = px.pie(df_education, values='total', names='Select Characteristics', title = 'Breakdown of sample by education level (2020-2022)')
fig4.show()
fig5 = px.pie(df_anxiety, values='total', names='Select Characteristics', title = 'Breakdown of sample by anxiety levels (2020-2022)')
fig5.show()
fig6 = px.pie(df_spending, values='total', names='Select Characteristics', title = 'Breakdown of sample by secondary income sources (2020-2022)')
fig6.show()

# save graphs as html files
'''
pio.write_html(fig, file='breakdown1.html', auto_open=True)
pio.write_html(fig2, file='breakdown2.html', auto_open=True)
pio.write_html(fig3, file='breakdown3.html', auto_open=True)
pio.write_html(fig4, file='breakdown4.html', auto_open=True)
pio.write_html(fig5, file='breakdown5.html', auto_open=True)
'''
pio.write_html(fig6, file='breakdown6.html', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad0c84bf-6d5e-4bd8-9e29-8f50980bbe70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad0c84bf-6d5e-4bd8-9e29-8f50980bbe70")) {                    Plotly.newPlot(                        "ad0c84bf-6d5e-4bd8-9e29-8f50980bbe70",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Select Characteristics=%{label}\u003cbr\u003etotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["    18 - 24","    25 - 39","    40 - 54","    55 - 64","    65 and above"],"legendgroup":"","name":"","showlegend":true,"values":[44949055,174951719,163503984,95156353,115631135],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f153de0-dea3-420d-bee4-2f24ae7123ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f153de0-dea3-420d-bee4-2f24ae7123ab")) {                    Plotly.newPlot(                        "2f153de0-dea3-420d-bee4-2f24ae7123ab",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Select Characteristics=%{label}\u003cbr\u003etotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["    Did not want to be employed","    Sick with coronavirus symptoms","    Caring for someone with coronavirus symptoms","    Caring for children not in school or daycare","    Caring for an elderly person","    Sick (not coronavirus related) or disabled","    Retired","    Coronavirus pandemic related reduction in business (including furlough)","    Laid off due to coronavirus pandemic","    Employment closed temporarily due to the coronavirus pandemic","    Employment went out of business due to the coronavirus pandemic","    Other reason","    Did not report"],"legendgroup":"","name":"","showlegend":true,"values":[11687924,4762862,11482615,9298465,6024974,16023461,85306941,25903969,14216968,20265744,3190074,37014689,349013559],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}] ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="501613f5-f25c-4e9c-a5e5-39c38dc2cf57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("501613f5-f25c-4e9c-a5e5-39c38dc2cf57")) {                    Plotly.newPlot(                        "501613f5-f25c-4e9c-a5e5-39c38dc2cf57",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Select Characteristics=%{label}\u003cbr\u003etotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["    Less than $25,000","    $25,000 - $34,999","    $35,000 - $49,999","    $50,000 - $74,999","    $75,000 - $99,999","    $100,000 - $149,999","    $150,000 - $199,999","    $200,000 and above","    Did not report"],"legendgroup":"","name":"","showlegend":true,"values":[68381493,51215643,55378233,78237604,58486340,67033066,30447262,33304848,151707757],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","wid ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d4583383-55d2-48a8-a3a4-5f7884da960c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4583383-55d2-48a8-a3a4-5f7884da960c")) {                    Plotly.newPlot(                        "d4583383-55d2-48a8-a3a4-5f7884da960c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Select Characteristics=%{label}\u003cbr\u003etotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["    Less than high school","    High school or GED","    Some college\u002fassociate’s degree","    Bachelor’s degree or higher"],"legendgroup":"","name":"","showlegend":true,"values":[48429433,186093979,179471018,180197814],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"co ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="30fd642f-a970-48d3-9705-b984103000b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30fd642f-a970-48d3-9705-b984103000b1")) {                    Plotly.newPlot(                        "30fd642f-a970-48d3-9705-b984103000b1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Select Characteristics=%{label}\u003cbr\u003etotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["    Not at all","    Several days","    More than half the days","    Nearly every day","    Did not report"],"legendgroup":"","name":"","showlegend":true,"values":[213461316,151246110,56937246,68647471,null],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlin ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c23818b6-4ac7-4aab-8bee-7a484b5bd9d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23818b6-4ac7-4aab-8bee-7a484b5bd9d5")) {                    Plotly.newPlot(                        "c23818b6-4ac7-4aab-8bee-7a484b5bd9d5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Select Characteristics=%{label}\u003cbr\u003etotal=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["    Regular income sources like those received before the pandemic","    Credit cards or loans","    Money from savings or selling assets or possessions","    Borrowing from friends or family","    Unemployment insurance (UI) benefit payments","    Stimulus (economic impact) payment","    Money saved from deferred or forgiven payments (to meet spending needs)","    Supplemental Nutrition Assistance Program (SNAP)","    Other"],"legendgroup":"","name":"","showlegend":true,"values":[214721091,81741964,59952530,32213925,16575365,66466740,9417981,21797956,26156026],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks": ...

# %%
# creatinf 2d list to hold characteristics and % for each year
characteristics = [[],[],[],[],[], []]
percentages2020 = [[],[],[],[],[], []]
percentages2021 = [[],[],[],[],[], []]
percentages2022 = [[],[],[],[],[], []]

# list of dataframes to iterate through
dataframes = [df_age, df_unemployment, df_income, df_education, df_anxiety, df_spending]
# helper variables for loop
count = 0
j = 0
i = 0

#loop through each dataframe in list
for dataframe in dataframes:
  count += 1
  # loop through each row
  for index, row in dataframe.iterrows():
    # appends characteristics
    characteristics[i].append(row['Select Characteristics'])
    # appends value for year
    percentages2020[i].append([])
    percentages2021[i].append([])
    percentages2022[i].append([])
    # calculates %s for 2020 if current dataframe is not last one
    if not count == 6:
      for column in dataframe.columns[2:7]:
        percentages2020[i][j].append(row[column] / row['1_total'] * 100)
        print(row[column])
      print("fiin")

    # calculates %s for 2021 if current dataframe is not last one
    if not count == 6:
      for column in dataframe.columns[8:13]:
        percentages2021[i][j].append(row[column] / row['2_total'] * 100)
    # calculates %s for 2021 if current dataframe is the last one
    else:
      for column in dataframe.columns[2:7]:
        percentages2021[i][j].append(row[column] / row['2_total'] * 100)

      #print(column)
    # calculates %s for 2022 if current dataframe is the last one
    if not count == 6:
      for column in dataframe.columns[14:19]:
        percentages2022[i][j].append(row[column] / row['3_total'] * 100)
      #print(column)
    # calculates %s for 2022 if current dataframe is the last one
    else:
      for column in dataframe.columns[8:13]:
        percentages2022[i][j].append(row[column] / row['3_total'] * 100)
    #increments row
    j+= 1
    print("test")
    # debugging purpose -> printing indez
    print(j)
  # increase dataframe index
  i+= 1
  print("done")
  # resets row index for next dataframe
  j = 0
print(characteristics)
print(percentages2020[0])
print(percentages2021[0])
print(len(percentages2020[0] + percentages2022[0] + percentages2021[0]))
# Out:
# 9828389
# 4036390
# 988302
# 128515
# 242676
# fiin
# test
# 1
# 49401376
# 16662003
# 6736827
# 1423693
# 1401257
# fiin
# test
# 2
# 43434586
# 12751205
# 4662314
# 1464483
# 991549
# fiin
# test
# 3
# 31263842
# 8293475
# 2410319
# 826879
# 614810
# fiin
# test
# 4
# 41611552
# 7662077
# 1048700
# 366556
# 919140
# fiin
# test
# 5
# done
# 2932446
# 574895
# 218582
# 1221
# 76648
# fiin
# test
# 1
# 524792
# 315649
# 138154
# 127722
# 3652
# fiin
# test
# 2
# 87112
# 22563
# 86191
# 5469
# 2997
# fiin
# test
# 3
# 3267210
# 1571995
# 996563
# 79770
# 79031
# fiin
# test
# 4
# 967160
# 541548
# 96068
# 117714
# 24897
# fiin
# test
# 5
# 3148293
# 1823936
# 1141380
# 335229
# 42192
# fiin
# test
# 6
# 30513629
# 5202592
# 749436
# 203012
# 392228
# fiin
# test
# 7
# 10596008
# 4476805
# 1731724
# 274982
# 197321
# fiin
# test
# 8
# 5844531
# 2859858
# 1357770
# 517652
# 208129
# fiin
# test
# 9
# 11450750
# 4120139
# 1326021
# 423925
# 183061
# fiin
# test
# 10
# 852857
# 435875
# 222892
# 73983
# 33458
# fiin
# test
# 11
# 7939336
# 2532897
# 1581437
# 603666
# 198957
# fiin
# test
# 12
# 97415621
# 24926395
# 6200244
# 1445782
# 2726860
# fiin
# test
# 13
# done
# 17133827
# 9618035
# 5901334
# 2047932
# 127151
# fiin
# test
# 1
# 15549522
# 6592797
# 3018351
# 507339
# 39359
# fiin
# test
# 2
# 19073450
# 6373823
# 1726076
# 386555
# 66460
# fiin
# test
# 3
# 28724977
# 8181219
# 1607013
# 387326
# 55689
# fiin
# test
# 4
# 22449776
# 5098640
# 604373
# 135606
# 38678
# fiin
# test
# 5
# 27155711
# 4347092
# 341457
# 126950
# 17551
# fiin
# test
# 6
# 12096667
# 1385108
# 98275
# 1891
# 4550
# fiin
# test
# 7
# 13219658
# 1061833
# 36591
# 19550
# 6388
# fiin
# test
# 8
# 20136158
# 6746602
# 2512992
# 596978
# 3813607
# fiin
# test
# 9
# done
# 8616307
# 4471575
# 2974455
# 1036608
# 569925
# fiin
# test
# 1
# 52216407
# 18028065
# 6481271
# 1693632
# 1505579
# fiin
# test
# 2
# 51987591
# 16630293
# 5106711
# 1153124
# 1050840
# fiin
# test
# 3
# 62719440
# 10275216
# 1284026
# 326764
# 1043088
# fiin
# test
# 4
# done
# 66771810
# 11182988
# 2847778
# 611301
# 149471
# fiin
# test
# 1
# 55593346
# 16393208
# 4124650
# 823683
# 144921
# fiin
# test
# 2
# 19167579
# 7414110
# 3170047
# 545751
# 63743
# fiin
# test
# 3
# 20953674
# 9463244
# 4234303
# 1877909
# 44738
# fiin
# test
# 4
# 13053336
# 4951598
# 1469685
# 351483
# 3766559
# fiin
# test
# 5
# done
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# done
# [['    18 - 24', '    25 - 39', '    40 - 54', '    55 - 64', '    65 and above'], ['    Did not want to be employed', '    Sick with coronavirus symptoms', '    Caring for someone with coronavirus symptoms', '    Caring for children not in school or daycare', '    Caring for an elderly person', '    Sick (not coronavirus related) or disabled', '    Retired', '    Coronavirus pandemic related reduction in business (including furlough)', '    Laid off due to coronavirus pandemic', '    Employment closed temporarily due to the coronavirus pandemic', '    Employment went out of business due to the coronavirus pandemic', '    Other reason', '    Did not report'], ['    Less than $25,000', '    $25,000 - $34,999', '    $35,000 - $49,999', '    $50,000 - $74,999', '    $75,000 - $99,999', '    $100,000 - $149,999', '    $150,000 - $199,999', '    $200,000 and above', '    Did not report'], ['    Less than high school', '    High school or GED', '    Some college/associate’s degree', '    Bachelor’s degree or higher'], ['    Not at all', '    Several days', '    More than half the days', '    Nearly every day', '    Did not report'], ['    Regular income sources like those received before the pandemic', '    Credit cards or loans', '    Money from savings or selling assets or possessions', '    Borrowing from friends or family', '    Unemployment insurance (UI) benefit payments', '    Stimulus (economic impact) payment', '    Money saved from deferred or forgiven payments (to meet spending needs)', '    Supplemental Nutrition Assistance Program (SNAP)', '    Other']]
# [[64.55736178666791, 26.51285877493132, 6.491620322362849, 0.8441453986012993, 1.5940071489784768], [65.32399880272644, 22.032355212596187, 8.90818261584809, 1.8825653728238259, 1.8528979960054561], [68.61255529002788, 20.14276728865287, 7.364943621299188, 2.3134080478816097, 1.5663257521384426], [72.02102774000747, 19.105284406057915, 5.55253738684027, 1.9048418744129287, 1.4163085926814112], [80.63000279510794, 14.846677430496516, 2.0320483103160796, 0.710269381554516, 1.7810020825249562]]
# [[43.86094334477057, 15.857324931827405, 5.571919177460643, 0.8890225124178749, 33.82079003352351], [55.185151663268584, 17.4506073466101, 7.634405971299884, 1.8243960735452047, 17.905437412261747], [57.39124121771816, 18.07320692123349, 7.503747790166226, 1.9169845670498256, 15.1148195038323], [62.800622376201865, 16.82687352352578, 5.226126258294587, 1.1432800674099821, 14.00309777456778], [71.15723798987659, 14.345936214528535, 2.4153577275867173, 0.8659824180085051, 11.215485649999644]]
# 15

# %%
# empty df w specified columns
age_diff_over_time = pd.DataFrame(columns=['Select Characteristic', 'Year', 'Level of Food Security', 'Percentage (within characteristic group)'])
# empty list to store characteristics
l = []
# loop through characteristics in first set
for char in characteristics[0]:
  for i in range(5):
    l.append(char)
# populate with characteristics
age_diff_over_time["Select Characteristic"] = l * 3
# populate with specified values
age_diff_over_time["Level of Food Security"] = ["Enough and all food", "Enough and some food", "Sometimes not enough", "Often not enough", "Did not report"] * 15
# populate with years
age_diff_over_time["Year"] = ["2020"] * 25 + ["2021"] * 25 + ["2022"] * 25
# empty list for %
w = []
# loop through each list of percentages
for val in percentages2020[0] + percentages2021[0] + percentages2022[0]:
  for sublist in val:
    # append % to list
    w.append(sublist)

# populate this column with the actual percentage values
age_diff_over_time["Percentage (within characteristic group)"] = w
#age_diff_over_time.style

# create line graph
lin = px.line(age_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security",line_group="Select Characteristic", line_dash = 'Select Characteristic', hover_name="Select Characteristic")
#lin = px.line(age_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security", hover_name="Select Characteristic")
lin.show()

# save line graphs
pio.write_html(lin, file='ageovertime.html', auto_open=True)

# create income df for %s
income_diff_over_time = pd.DataFrame(columns=['Select Characteristic', 'Year', 'Percentage (within characteristic group)'])
# populate year
income_diff_over_time["Year"] = ["2020"] * 9 + ["2021"] * 9 + ["2022"] * 9
# populate characteristics
income_diff_over_time["Select Characteristic"] = characteristics[2]*3
# empty list
w = []
#print(percentages2019[2])
# store percentages in empty list
for sub in percentages2020[2] + percentages2021[2] + percentages2022[2]:
    w.append(sub[0])

# populate column with values
income_diff_over_time["Percentage (within characteristic group)"] = w
# plot line
line2 = px.line(income_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Select Characteristic")
line2.show()
#save graph
pio.write_html(line2, file='incomeovertime.html', auto_open=True)

#fig = px.bar(age_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security", title = "Feelings of food security over time, grouped by age",  barmode="group", facet_col="Select Characteristic", facet_col_wrap=2)
#fig.show()
#fig2 = px.bar(income_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Select Characteristic")
#fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="872b6b3d-dd47-40a7-8da3-4d86048a3dad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("872b6b3d-dd47-40a7-8da3-4d86048a3dad")) {                    Plotly.newPlot(                        "872b6b3d-dd47-40a7-8da3-4d86048a3dad",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLevel of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    18 - 24\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["    18 - 24","    18 - 24","    18 - 24"],"legendgroup":"Enough and all food,     18 - 24","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Enough and all food,     18 - 24","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[64.55736178666791,43.86094334477057,45.8213253271465],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLevel of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    25 - 39\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["    25 - 39","    25 - 39","    25 - 39"],"legendgroup":"Enough and all food,     25 - 39","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"Enough and all food,     25 - 39","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[65.32399880272644,55.185151663268584,41.23672295964697],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLevel of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    40 - 54\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["    40 - 54","    40 - 54","    40 - 54"],"legendgroup":"Enough and all food,     40 - 54","line":{"color":"#636efa","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines","name":"Enough and all food,     40 - 54","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[68.61255529002788,57.39124121771816,46.07657215209008],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLevel of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    55 - 64\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["    55 - 64","    55 - 64","    55 - 64"],"legendgroup":"Enough and all food,     55 - 64","line":{"color":"#636efa","dash":"longdash"},"marker":{"symbol":"circle"},"mode":"lines","name":"Enough and all food,     55 - 64","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[72.02102774000747,62.800622376201865,42.37839385547018],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLevel of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    65 and above\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["    65 and above","    65 and above","    65 and above"],"legendgroup":"Enough and all food,     65 and above","line":{"color":"#636efa","dash":"dashdot"},"marker":{"symbol":"circle"},"mode":"lines","name":"Enough and all food,     65 and above","orientation":"v","showlegend":true,"x":["2020","2021","2022"], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="171f667a-99ad-4aca-b279-037e51421a6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("171f667a-99ad-4aca-b279-037e51421a6a")) {                    Plotly.newPlot(                        "171f667a-99ad-4aca-b279-037e51421a6a",                        [{"hovertemplate":"Select Characteristic=    Less than $25,000\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    Less than $25,000","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    Less than $25,000","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[49.19515833670679,44.30831064300088,31.965184425588944],"yaxis":"y","type":"scatter"},{"hovertemplate":"Select Characteristic=    $25,000 - $34,999\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    $25,000 - $34,999","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    $25,000 - $34,999","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[60.48663793534359,53.89244543692955,32.76347932577324],"yaxis":"y","type":"scatter"},{"hovertemplate":"Select Characteristic=    $35,000 - $49,999\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    $35,000 - $49,999","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    $35,000 - $49,999","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[69.04075396965015,63.14322395908687,43.28559131964086],"yaxis":"y","type":"scatter"},{"hovertemplate":"Select Characteristic=    $50,000 - $74,999\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    $50,000 - $74,999","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    $50,000 - $74,999","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[73.73655551771536,73.98440522546075,45.48269079625641],"yaxis":"y","type":"scatter"},{"hovertemplate":"Select Characteristic=    $75,000 - $99,999\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    $75,000 - $99,999","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    $75,000 - $99,999","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[79.25201169736063,80.56287640402749,63.37578201781935],"yaxis":"y","type":"scatter"},{"hovertemplate":"Select Characteristic=    $100,000 - $149,999\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    $100,000 - $149,999","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    $100,000 - $149,999","orientation":"v","showlegend":true,"x":["2020","2021","2022"],"xaxis":"x","y":[84.89141233072453,87.41816159573084,76.86215127943336],"yaxis":"y","type":"scatter"},{"hovertemplate":"Select Characteristic=    $150,000 - $199,999\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"    $150,000 - $199,999","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"    $150,000 - $199,999","orientation":"v","showlegend":true,"x":["2020","2021 ...

# %%
# make new df
edu_diff_over_time = pd.DataFrame(columns=['Select Characteristic', 'Year', 'Level of Food Security', 'Percentage (within characteristic group)'])
# empty list
l = []
# add characteristics to list
for char in characteristics[3]:
  for i in range(5):
    l.append(char)
# add characteristics to df
edu_diff_over_time["Select Characteristic"] = l * 3
# add values
edu_diff_over_time["Level of Food Security"] = ["Enough and all food", "Enough and some food", "Sometimes not enough", "Often not enough", "Did not report"] * 12
# add years
edu_diff_over_time["Year"] = ["2020"] * 20 + ["2021"] * 20 + ["2022"] * 20
# create list
w = []
# add all years %s to list
for val in percentages2022[3] + percentages2020[3] + percentages2021[3]:
  for sublist in val:
    w.append(sublist)
# save values in column
edu_diff_over_time["Percentage (within characteristic group)"] = w
# plot chart
fig = px.bar(edu_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security", title = "Feelings of food security over time, grouped by education", barmode="group", facet_col="Select Characteristic", facet_col_wrap=2)
fig.show()
# save file
pio.write_html(fig, file='eduovertime.html', auto_open=True)

# creates dataframes with the columns
emo_diff_over_time = pd.DataFrame(columns=['Select Characteristic', 'Year', 'Level of Food Security', 'Percentage (within characteristic group)'])
l = []
# loop through each characteristic in the first set
for char in characteristics[4]:
  # adds characteristic
  for i in range(5):
    l.append(char)
# add characteristics
emo_diff_over_time["Select Characteristic"] = l * 3
# add values
emo_diff_over_time["Level of Food Security"] = ["Enough and all food", "Enough and some food", "Sometimes not enough", "Often not enough", "Did not report"] * 15
# add years
emo_diff_over_time["Year"] = ["2020"] * 25 + ["2021"] * 25 + ["2022"] * 25
# create empty list
w = []
# add all %s to list
for val in percentages2022[4] + percentages2020[4] + percentages2021[4]:
  for sublist in val:
    w.append(sublist)
# populate column with %s
emo_diff_over_time["Percentage (within characteristic group)"] = w
# plot line
fig = px.bar(emo_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security", barmode="group", title = "Feelings of food security over time, grouped by level of anxiety", facet_col="Select Characteristic", facet_col_wrap=2)
fig.show()
#save graph
pio.write_html(fig, file='anxietyovertime.html', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e025bb31-6836-463b-a6ae-c24f53160a70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e025bb31-6836-463b-a6ae-c24f53160a70")) {                    Plotly.newPlot(                        "e025bb31-6836-463b-a6ae-c24f53160a70",                        [{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Less than high school\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":true,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x3","y":[25.061811693936047,48.76546441478915,36.859529463350114],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    High school or GED\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x4","y":[33.477654052978984,65.33179569089017,52.68751956469766],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Some college\u002fassociate’s degree\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x","y":[40.34516618636064,68.46908774429774,56.7039936882702],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Bachelor’s degree or higher\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x2","y":[67.87406847476402,82.90899705880615,75.04002726604679],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and some food\u003cbr\u003eSelect Characteristic=    Less than high school\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and some food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Enough and some food","offsetgroup":"Enough and some food","orientation":"v","showlegend":true,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x3","y":[23.982352583388852,25.307644161304932,21.68404752548065],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and some food\u003cbr\u003eSelect Characteristic=    High school or GED\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and some food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Enough and ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="390d2a9b-73db-4fd5-b0d3-5449a1db8b56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("390d2a9b-73db-4fd5-b0d3-5449a1db8b56")) {                    Plotly.newPlot(                        "390d2a9b-73db-4fd5-b0d3-5449a1db8b56",                        [{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Not at all\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":true,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x5","y":[70.92301446169091,81.86496954489901,85.21725029662659],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Several days\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x6","y":[54.89069193355739,72.12439511883066,64.17969057348212],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    More than half the days\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x3","y":[40.593655735554904,63.13176047215479,48.59366738332736],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Nearly every day\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x4","y":[30.780096970255176,57.291380829613104,40.89553625911968],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Did not report\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x","y":[null,55.327951348938555,20.612772348523674],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and some food\u003cbr\u003eSelect Characteristic=    Not at all\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and some food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Enough and some food","offsetgroup":"Enough and some food","orientation":"v","sho ...

# %%
# create df
emp_diff_over_time = pd.DataFrame(columns=['Select Characteristic', 'Year', 'Level of Food Security', 'Percentage (within characteristic group)'])
# create list
l = []
# add characteristics to list
for char in characteristics[1]:
  for i in range(5):
    l.append(char)
# add characteristics to df
emp_diff_over_time["Select Characteristic"] = l * 3
# add values to df
emp_diff_over_time["Level of Food Security"] = ["Enough and all food", "Enough and some food", "Sometimes not enough", "Often not enough", "Did not report"] * 39
# add years
emp_diff_over_time["Year"] = ["2020"] * 65 + ["2021"] * 65 + ["2022"] * 65
# empty list
w = []
# add percentage values to list
for val in percentages2020[1] + percentages2021[1] + percentages2022[1]:
  for sublist in val:
    w.append(sublist)
# add percentages to column
emp_diff_over_time["Percentage (within characteristic group)"] = w
# show graph
fig = px.bar(emp_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security", barmode="group", title = "Feelings of food security over time, grouped by unemployment", facet_col="Select Characteristic", facet_col_wrap=2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74a10f92-ce35-4857-ac8e-d969d4abe9a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a10f92-ce35-4857-ac8e-d969d4abe9a1")) {                    Plotly.newPlot(                        "74a10f92-ce35-4857-ac8e-d969d4abe9a1",                        [{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Did not want to be employed\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":true,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x13","y":[77.09270117819271,58.55793372361433,46.11223560900078],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Sick with coronavirus symptoms\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x14","y":[47.27987898761137,27.859300003503485,18.546550383290743],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Caring for someone with coronavirus symptoms\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x11","y":[42.63236971022791,41.357707379167344,38.18274553063285],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Caring for children not in school or daycare\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x12","y":[54.50283414871028,41.75506268081003,23.893289951431132],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Caring for an elderly person\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2020","2021","2022"],"xaxis":"x9","y":[55.34892957312834,31.61601785947624,14.879135538954108],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Sick (not coronavirus related) or disabled\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and  ...

# %%
# create new df
spe_diff_over_time = pd.DataFrame(columns=['Select Characteristic', 'Year', 'Level of Food Security', 'Percentage (within characteristic group)'])
# create new list
l = []
for char in characteristics[5]:
  # add characteristics to list
  for i in range(5):
    l.append(char)
# add characteristics to df
spe_diff_over_time["Select Characteristic"] = l * 2
# add values to df
spe_diff_over_time["Level of Food Security"] = ["Enough and all food", "Enough and some food", "Sometimes not enough", "Often not enough", "Did not report"] * 18
# add years to df
spe_diff_over_time["Year"] = ["2021"] * 45 + ["2022"] * 45
# create new list
w = []
# add all percentages to list
for val in percentages2021[5] + percentages2022[5]:
  for sublist in val:
    w.append(sublist)
    # save values in column
spe_diff_over_time["Percentage (within characteristic group)"] = w
# show graph
fig = px.bar(spe_diff_over_time, x="Year", y="Percentage (within characteristic group)", color="Level of Food Security", barmode="group", title = "Feelings of food security over time, grouped by secondary income sources", facet_col="Select Characteristic", facet_col_wrap=2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4df067e9-12e1-439b-8706-b02304fa97f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4df067e9-12e1-439b-8706-b02304fa97f8")) {                    Plotly.newPlot(                        "4df067e9-12e1-439b-8706-b02304fa97f8",                        [{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Regular income sources like those received before the pandemic\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":true,"textposition":"auto","x":["2021","2022"],"xaxis":"x9","y":[79.73420253573981,62.5384924776796],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Credit cards or loans\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2021","2022"],"xaxis":"x10","y":[59.09780664854085,46.554843108828166],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Money from savings or selling assets or possessions\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2021","2022"],"xaxis":"x7","y":[52.110368974744745,41.066926515061915],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Borrowing from friends or family\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2021","2022"],"xaxis":"x8","y":[23.387464055787127,18.30810448099942],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Unemployment insurance (UI) benefit payments\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup":"Enough and all food","orientation":"v","showlegend":false,"textposition":"auto","x":["2021","2022"],"xaxis":"x5","y":[49.48199270364827,36.48497790034528],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Level of Food Security=Enough and all food\u003cbr\u003eSelect Characteristic=    Stimulus (economic impact) payment\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage (within characteristic group)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Enough and all food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Enough and all food","offsetgroup" ...
